# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import cv2

# %%
image=cv2.imread("dog.jpg")

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (720, 1280, 3)

# %%
 plt.imshow(image)

# %%
# Cv2---> Blue Green Red
# matplotlib --> Red Green Blue

# %%
fixed_image= cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fixed_image)

# %%
image_gray= cv2.imread("dog.jpg",cv2.IMREAD_GRAYSCALE)

# %%
image_gray.shape
# Out:
# (720, 1280)

# %%
plt.imshow(image_gray, cmap="gray")

# %%
 plt.imshow(fixed_image)

# %%
 fixed_image.shape
# Out:
# (720, 1280, 3)

# %%
 new_image=cv2.resize(fixed_image,(900,600))

# %%
plt.imshow(new_image)

# %%
new_image= cv2.flip(fixed_image,1)

# %%
plt.imshow(new_image)

# %%
new_image= cv2.flip(fixed_image,-1)
plt.imshow(new_image)

# %%
cv2.imwrite("new_image_3.jpg",fixed_image)
# Out:
# True

# %%
image =cv2.imread('dog.jpg')
cv2.imshow('dog',image)
cv2.waitKey(0)
cv2.destroyAllWindows()
