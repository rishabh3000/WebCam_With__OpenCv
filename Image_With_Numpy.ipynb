# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from PIL import Image

# %%
picture=Image.open("dog.jpg")

# %%
picture
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x142BA875760>

# %%
type(picture)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
dog_arr=np.array(picture)

# %%
dog_arr
# Out:
# array([[[113,  72,  16],
#         [113,  72,  16],
#         [113,  73,  14],
#         ...,
#         [135,  90,  31],
#         [139,  94,  35],
#         [147, 102,  43]],
#
#        [[113,  72,  16],
#         [113,  72,  16],
#         [113,  73,  14],
#         ...,
#         [135,  90,  31],
#         [139,  94,  35],
#         [146, 101,  42]],
#
#        [[113,  72,  16],
#         [113,  72,  16],
#         [113,  73,  14],
#         ...,
#         [135,  90,  31],
#         [139,  94,  35],
#         [146, 101,  42]],
#
#        ...,
#
#        [[231, 208, 130],
#         [231, 208, 130],
#         [231, 208, 130],
#         ...,
#         [237, 210, 143],
#         [237, 210, 143],
#         [237, 210, 143]],
#
#        [[231, 208, 130],
#         [231, 208, 130],
#         [231, 208, 130],
#         ...,
#         [237, 210, 143],
#         [237, 210, 143],
#         [237, 210, 143]],
#
#        [[231, 208, 130],
#         [231, 208, 130],
#         [231, 208, 130],
# ...

# %%
dog_arr.shape
# Out:
# (720, 1280, 3)

# %%
plt.imshow(dog_arr)

# %%
plt.imshow(dog_arr[:,:, 0], cmap='gray')

# %%
plt.imshow(dog_arr[:,:, 1], cmap='gray')

# %%
plt.imshow(dog_arr[:,:, 2], cmap='gray')

# %%
dog_red=dog_arr.copy()

# %%
dog_red[:,:, 1] =0
dog_red[:,:, 2] =0

# %%
plt.imshow(dog_red)

# %%
dog_black=dog_arr.copy()

# %%
dog_black[:,:, 0] =0
dog_black[:,:, 2] =0

# %%
plt.imshow(dog_black)

# %%
dog_blue=dog_arr.copy()

# %%
dog_blue[:,:, 0] =0
dog_blue[:,:, 1] =0

# %%
plt.imshow(dog_blue)
